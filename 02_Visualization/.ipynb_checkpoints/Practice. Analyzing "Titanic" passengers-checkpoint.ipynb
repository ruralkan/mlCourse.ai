# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt

# %%
#Read data
trainDf = pd.read_csv('train.csv', index_col = 'PassengerId')

# %%
trainDf.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
trainDf.describe(include = 'all')
# Out:
#           Survived      Pclass                      Name   Sex         Age  \
# count   891.000000  891.000000                       891   891  714.000000
# unique         NaN         NaN                       891     2         NaN
# top            NaN         NaN  Moubarek, Master. Gerios  male         NaN
# freq           NaN         NaN                         1   577         NaN
# mean      0.383838    2.308642                       NaN   NaN   29.699118
# std       0.486592    0.836071                       NaN   NaN   14.526497
# min       0.000000    1.000000                       NaN   NaN    0.420000
# 25%       0.000000    2.000000                       NaN   NaN   20.125000
# 50%       0.000000    3.000000                       NaN   NaN   28.000000
# 75%       1.000000    3.000000                       NaN   NaN   38.000000
# max       1.000000    3.000000                       NaN   NaN   80.000000
#
# ...

# %%
trainDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
trainDf.shape
# Out:
# (891, 11)

# %%
pd.isnull(trainDf).head(5)
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# 1            False   True     False
# 2            False  False     False
# 3            False   True     False
# 4            False  False     False
# 5            False   True     False

# %% [markdown]
# **Let's dropCabin, and then – all rows with missing values.**

# %%
trainDf = trainDf.drop('Cabin', axis = 1).dropna()

# %%
trainDf.shape
# Out:
# (712, 10)

# %%
trainDf
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 19                  0       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 28                  0       1
# 31                  0       1
# 34                  0       2
# 35                  0       1
# 36                  0       1
# 38                  0       3
# ...

# %% [markdown]
# **1. Build a picture to visualize all scatter plots for each pair of features Age, Fare, SibSp, Parch and Survived. ( scatter_matrix from Pandas or pairplot from Seaborn)**

# %%
# pairplot() may become very slow with svg
# %config InlineBackend.figure_format = 'png'
features =['Age', 'Fare', 'Parch', 'Survived']
sns.pairplot(trainDf[features]);

# %%
pd.scatter_matrix(trainDf[features], figsize = (10,10));
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **2. How does ticket price (Fare) depend on Pclass? Build a boxplot.**

# %%
sns.boxplot(x = 'Pclass', y = 'Fare', data = trainDf);

# %% [markdown]
# **3. Let's build the same plot but restricting values of Fare to be less than 95% quantile of the initial vector (to drop outliers that make the plot less clear).**

# %%
sns.boxplot(x = 'Pclass', y = 'Fare', data = trainDf[trainDf.Fare < trainDf.Fare.quantile(.95)]);

# %% [markdown]
# **4. How is the percentage of surviving passengers dependent on passengers' gender? Depict it with Seaborn.countplot using the hue argument.**

# %%
sns.countplot(x = 'Sex', hue = 'Survived', data = trainDf);

# %%
sns.countplot(x = 'Pclass', hue = 'Survived', data = trainDf);

# %% [markdown]
# **5. How does the distribution of ticket prices differ for those who survived and those who didn't. Depict it with Seaborn.boxplot**

# %% [markdown]
# Sad truth, those who survived, typically had paid much more for their tickets.

# %%
sns.boxplot(x = 'Survived', y = 'Fare', data = trainDf[trainDf.Fare < 500]);

# %% [markdown]
# **6. How does survival depend on passengers' age? Verify (graphically) an assumption that youngsters (< 30 y.o.) survived more frequently than old people (> 55 y.o.).**

# %% [markdown]
# First aproach based in mean of age of survived

# %%
sns.boxplot(x = 'Survived', y = 'Age', data = trainDf)

# %% [markdown]
# The info not  is relevant, We can split by Classes.

# %%
sns.boxplot(x = 'Survived', y = 'Age', hue = 'Pclass', data = trainDf);

# %% [markdown]
# Now we categorize for age

# %%
trainDf['age_cat'] = trainDf['Age'].apply(lambda age: 1 if age < 30 
                                            else 3 if age > 55 else 2);

# %%
pd.crosstab(trainDf['age_cat'], trainDf['Survived'])
# Out:
# Survived    0    1
# age_cat
# 1         228  156
# 2         168  121
# 3          28   11

# %%
sns.countplot(x = 'age_cat', hue = 'Survived', data = trainDf);
